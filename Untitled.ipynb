# %%
import pandas as pd

# %%
df = pd.read_csv("transportation_cleaned.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 22 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Timestamp                                                                                             1042 non-null   object
#  1   How old are you?                                                                                      1042 non-null   object
#  2   What is your gender?                                                                                  1042 non-null   object
#  3   Where do you currently live?                                                                          1042 non-null   object
# ...

# %%
df.describe()
# Out:
#                       Timestamp How old are you? What is your gender?  \
# count                      1042             1042                 1042
# unique                     1042                4                    2
# top     2025-03-08 23:14:32.026      18-35 years                 Male
# freq                          1              416                  602
#
#        Where do you currently live?  \
# count                          1042
# unique                            8
# top                      kanakapura
# freq                            287
#
#        How would you rate the overall cleanliness of the public toilets you have used in the past month?  \
# count                                                  79
# unique                                                  4
# top                                                  Good
# freq                                                   31
#
#        How safe do you feel when using public toilets ?  \
# ...

# %%
df.head(5)
# Out:
#                  Timestamp How old are you? What is your gender?  \
# 0  2025-03-08 23:14:32.026      18-35 years               Female
# 1  2025-03-08 23:14:32.614      18-35 years               Female
# 2  2025-03-08 23:15:59.889      36-50 years               Female
# 3  2025-03-08 23:17:21.483      10-18 years                 Male
# 4  2025-03-08 23:17:27.195      51-70 years                 Male
#
#   Where do you currently live?  \
# 0                    palamaner
# 1                       mysuru
# 2                    palamaner
# 3                       mysuru
# 4                    Hyderabad
#
#   How would you rate the overall cleanliness of the public toilets you have used in the past month?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# ...
