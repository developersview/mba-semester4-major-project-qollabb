# %%
import pandas as pd

# %%
# Step 1: Load the dataset
filepath = "D:/AMITY/Semester_4/5. Major Project/mba-semester4-major-project-qollabb/ProjectApp/data/raw/citizen_feedback.csv"
df = pd.read_csv(filepath)
df.head(5)
# Out:
#   Age Group  Gender       City Cleanliness of public toilets  \
# 0    18-35   Female  Palamaner                          Good
# 1    18-35   Female     Mysuru                          Fair
# 2    36-50   Female  Palamaner                          Good
# 3    36-50     Male     Mysuru                          Poor
# 4    51-70     Male  Hyderabad                     Excellent
#
#   Safety of public toilets                         Features in public toilets  \
# 0          Somewhat unsafe  Accessible facilities for people with disabili...
# 1                Very safe  Accessible facilities for people with disabili...
# 2            Somewhat safe  Accessible facilities for people with disabili...
# 3                Very safe                          Comfortable seating areas
# 4                  Neutral  Accessible facilities for people with disabili...
#
#   Public Service Use Frequency of Public Service Use  \
# 0                Yes              A few times a week
# 1                 No                     Once a week
# 2                 No              A few times a week
# 3                Yes                     Once a week
# 4                Yes                        Everyday
#
#   Satisfaction of Pulic Transportation Suggestion for Pulic Transportation  \
# 0                              Neutral          More frequent buses/trains
# 1                          Unsatisfied       Increased safety and security
# 2                              Neutral          More frequent buses/trains
# 3                            Satisfied  Cleaner, more comfortable vehicles
# 4                              Neutral     Reduced fares or free transfers
#
#    ... Frequency of Visting of Local Parks Important Park amenities  \
# 0  ...    Increased programming and events              Picnic area
# 1  ...                      More amenities        Sports facilities
# 2  ...                      More amenities           Walking trails
# 3  ...        Improved lighting and safety              Picnic area
# 4  ...  Better maintenance and cleanliness        Sports facilities
#
#                   Issues in Park Safety of Public Transportation  \
# 0    Maintenance and cleanliness                              No
# 1  Accessibility and inclusivity                              No
# 2             Crowding and noise                              No
# 3            Safety and security                              No
# 4            Safety and security                             Yes
#
#                  Suggestion for Parks Satisfaction on Libraries resources  \
# 0  Electric vehicle charging stations                           Satisfied
# 1  Electric vehicle charging stations                           Satisfied
# 2  Electric vehicle charging stations                             Neutral
# 3                    Public restrooms                      Very Satisfied
# 4            Sports equipment rentals                        Dissatisfied
#
#   Frequency of Visiting Library Satisfaction of Local Public Service  \
# 0                         Never                              Neutral
# 1                        Weekly                    Very Dissatisfied
# 2                        Rarely                    Very Dissatisfied
# 3                       Monthly                              Neutral
# 4                        Weekly                         Dissatisfied
#
#           Suggestion for Libraries Suggestion for Local Public Service
# 0  DIY workshop(crafting,painting)                Invest in technology
# 1  DIY workshop(crafting,painting)            Improve customer service
# 2  DIY workshop(crafting,painting)                Invest in technology
# 3  DIY workshop(crafting,painting)               Increase transparency
# 4                    E book access            Improve customer service
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Age Group                                0
# Gender                                   0
# City                                     0
# Cleanliness of public toilets            0
# Safety of public toilets                 0
# Features in public toilets               0
# Public Service Use                       4
# Frequency of Public Service Use          4
# Satisfaction of Pulic Transportation     4
# Suggestion for Pulic Transportation      8
# Visting of Local Parks                   4
# Frequency of Visting of Local Parks      4
# Important Park amenities                 4
# Issues in Park                          12
# Safety of Public Transportation          4
# Suggestion for Parks                     4
# Satisfaction on Libraries resources      4
# Frequency of Visiting Library            4
# Satisfaction of Local Public Service     4
# Suggestion for Libraries                 8
# Suggestion for Local Public Service      8
# dtype: int64

# %%
# Step 2: Drop rows with too many missing values (optional but safe)
df.dropna(thresh=15, inplace=True)  # Keep rows with at least 15 non-NaN values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4164 entries, 0 to 4167
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Age Group                             4164 non-null   object
#  1   Gender                                4164 non-null   object
#  2   City                                  4164 non-null   object
#  3   Cleanliness of public toilets         4164 non-null   object
#  4   Safety of public toilets              4164 non-null   object
#  5   Features in public toilets            4164 non-null   object
#  6   Public Service Use                    4164 non-null   object
#  7   Frequency of Public Service Use       4164 non-null   object
#  8   Satisfaction of Pulic Transportation  4164 non-null   object
#  9   Suggestion for Pulic Transportation   4160 non-null   object
#  10  Visting of Local Parks                4164 non-null   object
#  11  Frequency of Visting of Local Parks   4164 non-null   object
#  12  Important Park amenities              4164 non-null   object
#  13  Issues in Park                        4156 non-null   object
#  14  Safety of Public Transportation       4164 non-null   object
#  15  Suggestion for Parks                  4164 non-null   object
#  16  Satisfaction on Libraries resources   4164 non-null   object
#  17  Frequency of Visiting Library         4164 non-null   object
#  18  Satisfaction of Local Public Service  4164 non-null   object
#  19  Suggestion for Libraries              4160 non-null   object
#  20  Suggestion for Local Public Service   4160 non-null   object
# dtypes: object(21)
# memory usage: 715.7+ KB

# %%
# Step 3: Fill remaining missing values with "Unknown" or appropriate placeholder
df.fillna("Unknown", inplace=True)

# %%
df.isnull().sum()
# Out:
# Age Group                               0
# Gender                                  0
# City                                    0
# Cleanliness of public toilets           0
# Safety of public toilets                0
# Features in public toilets              0
# Public Service Use                      0
# Frequency of Public Service Use         0
# Satisfaction of Pulic Transportation    0
# Suggestion for Pulic Transportation     0
# Visting of Local Parks                  0
# Frequency of Visting of Local Parks     0
# Important Park amenities                0
# Issues in Park                          0
# Safety of Public Transportation         0
# Suggestion for Parks                    0
# Satisfaction on Libraries resources     0
# Frequency of Visiting Library           0
# Satisfaction of Local Public Service    0
# Suggestion for Libraries                0
# Suggestion for Local Public Service     0
# dtype: int64

# %%
# Step 4: Rename columns for ease of use (short and Pythonic)
df.columns = [
    "age_group", "gender", "city", "toilet_cleanliness", "toilet_safety",
    "toilet_features", "service_use", "service_use_freq", "transport_satisfaction",
    "transport_suggestions", "park_visiting", "park_visit_freq", "park_amenities",
    "park_issues", "transport_safety", "park_suggestions", "library_satisfaction",
    "library_visit_freq", "local_service_satisfaction", "library_suggestions",
    "local_service_suggestions"
]

# Step 5: Preview cleaned dataset
print("🧹 Cleaned Data Sample:")
df.head()
# Out:
# 🧹 Cleaned Data Sample:
#   age_group  gender       city toilet_cleanliness    toilet_safety  \
# 0    18-35   Female  Palamaner               Good  Somewhat unsafe
# 1    18-35   Female     Mysuru               Fair        Very safe
# 2    36-50   Female  Palamaner               Good    Somewhat safe
# 3    36-50     Male     Mysuru               Poor        Very safe
# 4    51-70     Male  Hyderabad          Excellent          Neutral
#
#                                      toilet_features service_use  \
# 0  Accessible facilities for people with disabili...         Yes
# 1  Accessible facilities for people with disabili...          No
# 2  Accessible facilities for people with disabili...          No
# 3                          Comfortable seating areas         Yes
# 4  Accessible facilities for people with disabili...         Yes
#
#      service_use_freq transport_satisfaction  \
# 0  A few times a week                Neutral
# 1         Once a week            Unsatisfied
# 2  A few times a week                Neutral
# 3         Once a week              Satisfied
# 4            Everyday                Neutral
#
#                 transport_suggestions  ...  \
# 0          More frequent buses/trains  ...
# 1       Increased safety and security  ...
# 2          More frequent buses/trains  ...
# 3  Cleaner, more comfortable vehicles  ...
# 4     Reduced fares or free transfers  ...
#
#                       park_visit_freq     park_amenities  \
# 0    Increased programming and events        Picnic area
# 1                      More amenities  Sports facilities
# 2                      More amenities     Walking trails
# 3        Improved lighting and safety        Picnic area
# 4  Better maintenance and cleanliness  Sports facilities
#
#                      park_issues transport_safety  \
# 0    Maintenance and cleanliness               No
# 1  Accessibility and inclusivity               No
# 2             Crowding and noise               No
# 3            Safety and security               No
# 4            Safety and security              Yes
#
#                      park_suggestions library_satisfaction library_visit_freq  \
# 0  Electric vehicle charging stations            Satisfied              Never
# 1  Electric vehicle charging stations            Satisfied             Weekly
# 2  Electric vehicle charging stations              Neutral             Rarely
# 3                    Public restrooms       Very Satisfied            Monthly
# 4            Sports equipment rentals         Dissatisfied             Weekly
#
#   local_service_satisfaction              library_suggestions  \
# 0                    Neutral  DIY workshop(crafting,painting)
# 1          Very Dissatisfied  DIY workshop(crafting,painting)
# 2          Very Dissatisfied  DIY workshop(crafting,painting)
# 3                    Neutral  DIY workshop(crafting,painting)
# 4               Dissatisfied                    E book access
#
#   local_service_suggestions
# 0      Invest in technology
# 1  Improve customer service
# 2      Invest in technology
# 3     Increase transparency
# 4  Improve customer service
#
# [5 rows x 21 columns]

# %%
# Step 6: Save the cleaned data for next phase (optional)
filepath = "D:/AMITY/Semester_4/5. Major Project/mba-semester4-major-project-qollabb/ProjectApp/data/preprocessed/cleaned_citizen_feedback.csv"
df.to_csv(filepath, index=False)
